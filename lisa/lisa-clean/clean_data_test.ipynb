# %%
import pandas as pd
from pathlib import Path
import os

# %%
Dadong_file = pd.read_csv("/Users/lisashan/Tibame-TJR101-T1/lisa/lisa-crawler/data/output/store_comment/Dadong Night Market/20250425_crawler_Dadong Night Market_rawdata.csv")
Flower_file = pd.read_csv("/Users/lisashan/Tibame-TJR101-T1/lisa/lisa-crawler/data/output/store_comment/Tainan Flower Night Market/20250425_crawler_Tainan Flower Night Market_rawdata.csv")
Wusheng_file = pd.read_csv("/Users/lisashan/Tibame-TJR101-T1/lisa/lisa-crawler/data/output/store_comment/Wusheng Night Market/20250425_crawler_Wusheng Night Market_rawdata.csv")

files = pd.concat([Dadong_file, Flower_file, Wusheng_file])

print(files.head())
# Out:
#    餐廳名稱               留言者                    留言者身分    留言時間  星級評等  \
# 0  大東夜市                小晴    在地嚮導 · 36 則評論 · 5 張相片  37 分鐘前  1 顆星
# 1  大東夜市      Chang Duncan   在地嚮導 · 26 則評論 · 12 張相片  13 小時前  2 顆星
# 2  大東夜市  Shuk Chun Cheung  在地嚮導 · 170 則評論 · 44 張相片  23 小時前  4 顆星
# 3  大東夜市               高菀妤    在地嚮導 · 25 則評論 · 3 張相片    1 天前  5 顆星
# 4  大東夜市               顏書舲   在地嚮導 · 28 則評論 · 27 張相片    1 天前  5 顆星
#
#                                                 評論內容
# 0  一顆星給槍射氣球的老闆，還沒完就問老闆一局多少老闆就說錢不用管打就對了，而且還卡彈兩三次說要...
# 1                           人擠爆 …擠了一圈。花了1個多小時買了個排骨酥…
# 2                             好多食物選擇，但有鐵板牛排就有d懷疑牛嘅成份
# 3                                              非常好逛逛
# 4                                                NaN
