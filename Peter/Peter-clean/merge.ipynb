# %%
import pandas as pd
import glob

# %%
files = glob.glob("Peter/Data/StoreList*.csv")

# %%
# 檢查是否有符合條件的檔案
if not files:
    print("❌ 找不到任何符合條件的 CSV 檔案！請檢查路徑或檔案名稱是否正確。")
else:
    print(f"找到 {len(files)} 個檔案：", files)
# Out:
# ❌ 找不到任何符合條件的 CSV 檔案！請檢查路徑或檔案名稱是否正確。
